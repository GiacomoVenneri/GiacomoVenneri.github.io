# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# !cd gdrive/MyDrive/DataMining/Progetto
# Out:
# Mounted at /content/gdrive/
# /bin/bash: line 0: cd: gdrive/MyDrive/DataMining/Progetto: No such file or directory

# %%
import networkx as nx
import pandas as pd
import json
from tqdm import tqdm_notebook as tqdm

# %%
# !pip install crossrefapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting crossrefapi
#   Downloading crossrefapi-1.5.0.tar.gz (20 kB)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from crossrefapi) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.11.1->crossrefapi) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.11.1->crossrefapi) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.11.1->crossrefapi) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.11.1->crossrefapi) (2022.6.15)
# Building wheels for collected packages: crossrefapi
#   Building wheel for crossrefapi (setup.py) ... done
#   Created wheel for crossrefapi: filename=crossrefapi-1.5.0-py3-none-any.whl size=15716 sha256=def3dfd29f43caa82a91fec0c45c7cd75adc8c87b19278ac2773d3a5831801aa
#   Stored in directory: /root/.cache/pip/wheels/6b/80/c9/1858fe009591baf8a4406f169332897b51576f129803584326
# Successfully built crossrefapi
# Installing collected packages: crossrefapi
# Successfully installed crossrefapi-1.5.0

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re
from tqdm import tqdm
from crossref.restful import Works
import time

# %%
data=pd.read_json('/content/gdrive/MyDrive/DataMining/progetto/datasets/dataset_raw_7001.json')
data
# Out:
#                                DOI  \
# 0        10.1186/s40635-019-0284-8
# 1     10.1371/journal.pone.0226483
# 2        10.1186/s12879-019-4724-6
# 3        10.1186/s12936-019-3096-0
# 4        10.1186/s13756-019-0669-1
# ...                            ...
# 6987          10.1093/cid/ciaa1419
# 6988    10.1016/j.tins.2020.10.006
# 6989     10.18632/oncotarget.27819
# 6990    10.1016/j.ijid.2019.10.009
# 6991          10.1029/2020gh000319
#
#                                                   Title First_author  \
# 0     Aortic volume determines global end-diastolic ...       Akohov
# 1     Risk perception and behavioral change during e...  Abdulkareem
# 2     Effect of prior receipt of antibiotics on the ...           Li
# 3     Genetic polymorphisms in malaria vaccine candi...      Ajibaye
# 4     Enhanced infection control interventions reduc...         Phan
# ...                                                 ...          ...
# 6987  Risk Factors for COVID-19-associated hospitali...           Ko
# 6988  Neuroethical and Societal Challenges of 21st C...     Minielly
# 6989  Treatment of elderly patients with refractory/...       Xavier
# 6990  Epidemiological characteristics and phylogenic...          Luo
# 6991  Compound Risks of Hurricane Evacuation Amid th...          Pei
#
#                         Nation Publish_time  \
# 0                      Germany   2020-01-02
# 1                  Netherlands   2020-01-06
# 2                        China   2020-01-06
# 3                        Niger   2020-01-06
# 4                      Vietnam   2020-01-07
# ...                        ...          ...
# 6987  United States of America   2020-09-18
# 6988                    Canada   2020-10-22
# 6989                    Brazil   2020-11-24
# 6990                     China   2020-01-31
# 6991  United States of America   2020-12-01
#
#                                            Journal                    Topic  \
# 0                           Intensive Care Med Exp            Hospital Care
# 1                                         PLoS One        Societal response
# 2                                   BMC Infect Dis            Hospital Care
# 3                                          Malar J            Hospital Care
# 4                 Antimicrob Resist Infect Control  Viral molecular biology
# ...                                            ...                      ...
# 6987                               Clin Infect Dis            Hospital Care
# 6988                               Trends Neurosci        Societal response
# 6989                                    Oncotarget        Societal response
# 6990  International Journal of Infectious Diseases            Hospital Care
# 6991                                     Geohealth        Societal response
#
#                                                  URL  \
# 0        http://dx.doi.org/10.1186/s40635-019-0284-8
# 1     http://dx.doi.org/10.1371/journal.pone.0226483
# 2        http://dx.doi.org/10.1186/s12879-019-4724-6
# 3        http://dx.doi.org/10.1186/s12936-019-3096-0
# 4        http://dx.doi.org/10.1186/s13756-019-0669-1
# ...                                              ...
# 6987          http://dx.doi.org/10.1093/cid/ciaa1419
# 6988    http://dx.doi.org/10.1016/j.tins.2020.10.006
# 6989     http://dx.doi.org/10.18632/oncotarget.27819
# 6990    http://dx.doi.org/10.1016/j.ijid.2019.10.009
# 6991          http://dx.doi.org/10.1029/2020gh000319
#
#                                            reference_to      PMID  \
# 0     [10.1186/s13054-017-1739-5, 10.1097/EJA.000000...  31897796
# 1     [10.1057/hs.2014.22, 10.1093/her/cyg074, 10.10...  31905206
# 2     [10.1093/cid/cis1021, 10.1016/0732-8893(87)901...  31906848
# 3     [10.1038/415673a, 10.1016/j.vaccine.2016.10.04...  31906953
# 4     [10.1093/cid/cir257, 10.1016/j.jhin.2010.09.01...  31921415
# ...                                                 ...       ...
# 6987  [10.1056/NEJMoa2002032, 10.1136/bmj.m1985, 10....  32945846
# 6988  [10.1016/j.jns.2020.116884, 10.3390/ijerph1718...  33153756
# 6989  [10.1056/NEJMra1011442, 10.1200/JCO.2008.20.89...  33316011
# 6990  [10.1590/S0074-02762005000300001, 10.1007/s007...  31634614
# 6991  [10.1016/j.apgeog.2010.05.002, 10.1289/ehp.120...  33299960
#
#                                                 citedBy
# 0                        [35760382, 34775842, 33573169]
# 1     [35761390, 35722244, 35444590, 35329823, 35070...
# 2                                  [34625886, 34621317]
# 3              [35737709, 34162366, 33500482, 32630804]
# 4                                  [35795519, 33434666]
# ...                                                 ...
# 6987  [36050992, 36046662, 36042485, 35897262, 35885...
# 6988                                         [33935846]
# 6989                                         [34043442]
# 6990  [35875547, 35632566, 34532066, 34425845, 34131...
# 6991  [35896977, 35663638, 35308103, 35035122, 34995...
#
# [6992 rows x 11 columns]

# %%
data = data[['DOI', 'reference_to', 'citedBy', 'PMID']]

# %%
dois = data['DOI'].tolist()
pmids = data['PMID'].tolist()
C_BY = data["citedBy"]
print(len(dois))
print(len(pmids))
print(len(C_BY))
# Out:
# 6992
# 6992
# 6992

# %%
G = nx.DiGraph()

# %% [markdown]
# # ***test***

# %%
def doi_from_pmid(pmid):
  root = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/?email=vennerigiacomo98@gmail.com&"
  page = requests.get(root+"ids="+pmid)
                   
  if (page.status_code == 200):
      soup = BeautifulSoup(page.content, 'html.parser')
      records = str(soup.findAll("record"))
      cby_dois=re.findall(r'(?<=doi=")([^ ]*)(?=" )',records)
      if(len(cby_dois) >0): return cby_dois[0]
  else:
      print("errore", pmid)

# %%
doi_from_pmid("34625886")
# Out:
# '10.1007/s10096-021-04354-8'

# %%
for i in tqdm(data.iterrows()):
  node = i[1]["DOI"]
  node_pmid = i[1]["PMID"]
  
  for j in i[1]["reference_to"]:
    if( j in dois and j!=node):
      G.add_node(node)
      G.add_edge(node, j)
      G.add_edge(j, node)
  for j in i[1]["citedBy"]:
    if( j in pmids and j!=node_pmid):
      current_doi = doi_from_pmid(j)
      if(j is not None):
        G.add_node(node)
        G.add_edge(current_doi, node)
        G.add_edge(node, current_doi)

print("Nodi: ",len(G.nodes()))
print("Archi: ",len(G.edges()))
# Out:
# 6992it [01:00, 116.02it/s]
# Nodi:  746
# Archi:  1212

# %%
#be sure that duplicates doesnèt exists
G.remove_edges_from(nx.selfloop_edges(G))
print("Nodi: ",len(G.nodes()))
print("Archi: ",len(G.edges()))
# Out:
# Nodi:  746
# Archi:  1212

# %%
nx.draw(G)

# %%
between = nx.algorithms.centrality.betweenness_centrality(G)
df_between = pd.DataFrame(columns = ['DOI', 'betweennes'])
for i in between.keys():
  df_between = df_between.append({'DOI' : i, 'betweennes' : between[i]}, ignore_index = True)

column = "betweennes"
df_between[column] = df_between[column] /df_between[column].abs().max()
df_between[column]
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 741    0.000000
# 742    0.000000
# 743    0.000000
# 744    0.000137
# 745    0.000000
# Name: betweennes, Length: 746, dtype: float64

# %%
data_out = df_between.to_json(orient = "records")
data_out = json.loads(data_out)
with open('dataset_between_7001_v3.json', 'w') as f:
    json.dump(data_out, f, indent = 4)

# %%
#only for direceted graphs
in_deg = nx.algorithms.centrality.in_degree_centrality(G)
df_in_deg = pd.DataFrame(columns = ['DOI', 'in_deg'])
for i in in_deg.keys():
  df_in_deg = df_in_deg.append({'DOI' : i, 'in_deg' : in_deg[i]}, ignore_index = True)

column = "in_deg"
df_in_deg[column] = df_in_deg[column] /df_in_deg[column].abs().max()
df_in_deg[column]
# Out:
# 0      0.03125
# 1      0.03125
# 2      0.03125
# 3      0.03125
# 4      0.03125
#         ...
# 741    0.03125
# 742    0.03125
# 743    0.03125
# 744    0.06250
# 745    0.03125
# Name: in_deg, Length: 746, dtype: float64

# %%
data_out = df_in_deg.to_json(orient = "records")
data_out = json.loads(data_out)
with open('dataset_indeg_7001_v3.json', 'w') as f:
    json.dump(data_out, f, indent = 4)
